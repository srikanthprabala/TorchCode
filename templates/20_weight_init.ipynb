# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanthprabala/TorchCode/blob/master/templates/20_weight_init.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/20_weight_init.ipynb)
#
# # 🟢 Easy: Kaiming Initialization
#
# Implement **Kaiming (He) normal initialization** for weight tensors.
#
# $$W \sim \mathcal{N}(0, \text{std}^2) \quad \text{where} \quad \text{std} = \sqrt{\frac{2}{\text{fan\_in}}}$$
#
# ### Signature
# ```python
# def kaiming_init(weight: Tensor) -> Tensor:
#     # Initialize weight in-place with Kaiming normal
#     # fan_in = weight.shape[1]
#     # Returns the weight tensor
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.2 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def kaiming_init(weight):
    # fill with normal(0, sqrt(2/fan_in))
    fan_in = weight.shape[1]
    std = math.sqrt(2/fan_in)
    with torch.no_grad():
      weight.normal_(0, std)
    return weight

# %%
# 🧪 Debug
import math
w = torch.empty(256, 512)
kaiming_init(w)
print(f'Mean: {w.mean():.4f} (expect ~0)')
print(f'Std:  {w.std():.4f} (expect {math.sqrt(2/512):.4f})')
# Out:
# Mean: -0.0002 (expect ~0)
# Std:  0.0627 (expect 0.0625)

# %%
# ✅ SUBMIT
from torch_judge import check, hint, status

hint('weight_init')
check('weight_init')
status()
# Out:
# 💡 Hint for Kaiming Initialization:
#    For fan_in mode: std = sqrt(2 / fan_in) where fan_in = weight.shape[1]. Fill with normal(0, std). Return the tensor.
#
#
# 🧪 Testing: Kaiming Initialization (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Mean approximately 0 (4.8ms)
#   ✅ [2/4] Std matches sqrt(2/fan_in) (4.3ms)
#   ✅ [3/4] Returns same tensor (in-place) (0.2ms)
#   ✅ [4/4] Smaller fan_in gives larger std (0.5ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (9.7ms total)
#   Progress saved. Run status() to see your dashboard.
#
#
# ────────────────────────────────────────────────────────
#   🔥 TorchCode Progress: 1/40 solved
# ────────────────────────────────────────────────────────
#   ⏳ cross_entropy        [Easy]
#      Cross-Entropy Loss
#   ⏳ dropout              [Easy]
#      Implement Dropout
#   ⏳ embedding            [Easy]
#      Embedding Layer
#   ⏳ gelu                 [Easy]
#      GELU Activation
#   ⏳ gradient_accumulation [Easy]
#      Gradient Accumulation
#   ⏳ gradient_clipping    [Easy]
#      Gradient Norm Clipping
#   ⏳ relu                 [Easy]
#      Implement ReLU
#   ⏳ softmax              [Easy]
#      Implement Softmax
#   ✅ weight_init          [Easy]  ⚡ 8.6ms  (4 attempts)
#      Kaiming Initialization
#   ⏳ adam                 [Medium]
#      Adam Optimizer
#   ⏳ batchnorm            [Medium]
#      Implement BatchNorm
#   ⏳ beam_search          [Medium]
#      Beam Search Decoding
#   ⏳ conv2d               [Medium]
#      2D Convolution
#   ⏳ cosine_lr            [Medium]
#      Cosine LR Scheduler with Warmup
#   ⏳ cross_attention      [Medium]
#      Multi-Head Cross-Attention
#   ⏳ layernorm            [Medium]
#      Implement LayerNorm
#   ⏳ linear               [Medium]
#      Simple Linear Layer
#   ⏳ linear_regression    [Medium]
#      Linear Regression
#   ⏳ lora                 [Medium]
#      LoRA (Low-Rank Adaptation)
#   ⏳ mlp                  [Medium]
#      SwiGLU MLP
#   ⏳ rmsnorm              [Medium]
#      Implement RMSNorm
#   ⏳ topk_sampling        [Medium]
#      Top-k / Top-p Sampling
#   ⏳ vit_patch            [Medium]
#      ViT Patch Embedding
#   ⏳ attention            [Hard]
#      Softmax Attention
#   ⏳ bpe                  [Hard]
#      Byte-Pair Encoding (BPE)
#   ⏳ causal_attention     [Hard]
#      Causal Self-Attention
#   ⏳ dpo_loss             [Hard]
#      DPO (Direct Preference Optimization) Loss
#   ⏳ flash_attention      [Hard]
#      Flash Attention (Tiled)
#   ⏳ gpt2_block           [Hard]
#      GPT-2 Transformer Block
#   ⏳ gqa                  [Hard]
#      Grouped Query Attention
#   ⏳ grpo_loss            [Hard]
#      GRPO (Group Relative Policy Optimization) Loss
#   ⏳ int8_quantization    [Hard]
#      INT8 Quantized Linear
#   ⏳ kv_cache             [Hard]
#      KV Cache Attention
#   ⏳ linear_attention     [Hard]
#      Linear Self-Attention
#   ⏳ mha                  [Hard]
#      Multi-Head Attention
#   ⏳ moe                  [Hard]
#      Mixture of Experts (MoE)
#   ⏳ ppo_loss             [Hard]
#      PPO (Proximal Policy Optimization) Clipped Loss
#   ⏳ rope                 [Hard]
#      Rotary Position Embedding (RoPE)
#   ⏳ sliding_window       [Hard]
#      Sliding Window Attention
#   ⏳ speculative_decoding [Hard]
#      Speculative Decoding
# ────────────────────────────────────────────────────────
